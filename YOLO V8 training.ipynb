# %%
#uploaded the labelled dataset from roboflow 
#dataset was in YOLO V* fromat
#also move the dataset file into the ultralytics file

# %%
#intsall required libraries from ultralytics and clone yolo v8 repository from git hub to use pretrained models

# %%
# !pip install ultralytics

# %%
# !git clone https://github.com/ultralytics/ultralytics
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 17125, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 17125 (delta 9), reused 26 (delta 6), pack-reused 17085
# Receiving objects: 100% (17125/17125), 9.02 MiB | 7.94 MiB/s, done.
# Resolving deltas: 100% (11948/11948), done.

# %%
cd ultralytics
# Out:
# /content/ultralytics

# %%
# !nvidia-smi
# Out:
# Sun Oct 29 15:29:28 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content/ultralytics

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.202 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 27.4/78.2 GB disk)

# %%
from IPython import display
display.clear_output()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
import torch
torch.cuda.empty_cache()

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO('yolov8m.yaml')

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8m.pt')

# Train the model
results = model.train(data='/content/ultralytics/dataset/data.yaml', epochs=10, batch=10, imgsz=612)



# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model('/content/ultralytics/dataset/test/images/a-50-_jpg.rf.e02d6fb3ec6dc01f8d4acc860cae8edf.jpg')

# Export the model to ONNX format
success = model.export(format='onnx')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
# ...

# %%
import cv2

import matplotlib.pyplot as plt

img = cv2.imread('/content/ultralytics/runs/detect/train4/results.png')
plt.imshow(img)
plt.show()

# %%
import cv2

import matplotlib.pyplot as plt

img = cv2.imread('/content/ultralytics/runs/detect/train4/confusion_matrix.png')
plt.imshow(img)
plt.show()

# %%
import cv2

import matplotlib.pyplot as plt

img = cv2.imread('/content/ultralytics/runs/detect/train4/val_batch0_pred.jpg')
plt.imshow(img)
plt.show()

# %%
import cv2

import matplotlib.pyplot as plt

img = cv2.imread('/content/ultralytics/runs/detect/train4/val_batch1_pred.jpg')
plt.imshow(img)
plt.show()

# %%
import cv2
from PIL import Image

# Load the model
model = YOLO("/content/ultralytics/runs/detect/train4/weights/best.pt")  # Detection (Nano Model)

# Predictions for Directory Folder, videos, images, and webcam
model.predict(source="/content/ultralytics/dataset/test/images/copy_0c-29-_jpg.rf.b3a58bb618df289a8bf317f937b1b247.jpg", show=True, save=True)

# %%
import cv2

import matplotlib.pyplot as plt

img = cv2.imread('/content/ultralytics/runs/detect/predict/copy_0c-29-_jpg.rf.b3a58bb618df289a8bf317f937b1b247.jpg')
plt.imshow(img)
plt.show()

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO('yolov8l.yaml')

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8l.pt')

# Train the model
results = model.train(data='/content/ultralytics/dataset/data.yaml', epochs=10, batch=10, imgsz=612)



# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model('/content/ultralytics/dataset/test/images/a-50-_jpg.rf.e02d6fb3ec6dc01f8d4acc860cae8edf.jpg')

# Export the model to ONNX format
success = model.export(format='onnx')

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO('yolov8l.yaml')

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8l.pt')

# Train the model
results = model.train(data='/content/ultralytics/pipe-inventory-7/data.yaml', epochs=10, batch=10, imgsz=612 , optimizer='SGD')



# Evaluate the model's performance on the validation set
results = model.val()

# Perform object detection on an image using the model
results = model('/content/ultralytics/pipe-inventory-7/test/images/a-50-_jpg.rf.e02d6fb3ec6dc01f8d4acc860cae8edf.jpg')

# Export the model to ONNX format
success = model.export(format='onnx')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  3    279808  ultralytics.nn.modules.block.C2f             [128, 128, 3, True]
#   3                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   4                  -1  6   2101248  ultralytics.nn.modules.block.C2f             [256, 256, 6, True]
#   5                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   6                  -1  6   8396800  ultralytics.nn.modules.block.C2f             [512, 512, 6, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
# ...

# %%
#saving the best.pt file for deployment from run file iof ultralytics
